# %%
#importo librerias necesarias
#!pip install ipython-sql
# Install the 'ipython-sql' and 'prettytable' libraries using pip
#!pip install ipython-sql prettytable

#Metodo para conectarse y cerrar la conexion a mano
from sqlalchemy import create_engine

# Import the 'prettytable' library, which is used to display data in a formatted table
import prettytable
# Set the default display format for prettytable to 'DEFAULT' (i.e., a simple table format)
prettytable.DEFAULT = 'DEFAULT'
#para manejar las passwords con las variables de ambiente
import os
# Load environment variables from .env file
from dotenv import load_dotenv
load_dotenv()


#cargo el magic command de alchemysql
# %load_ext sql

#NOTA:
#En todos los statemens que corras, es necesario terminar con ; para que funcione

# %%
#mysql
psw_mysql = os.getenv("MYSQL_PSW")
DATABASE_URL_mysql = f"mysql+mysqlconnector://root:{psw_mysql}@127.0.0.1:3306/exampleDB"

try:
    engine_mysql = create_engine(DATABASE_URL_mysql)
    connection_mysql = engine_mysql.connect()
    # %sql $DATABASE_URL_mysql
    print(f"Connected successfully to {str(engine_mysql.url)}!")
except Exception as e:
    print(f"Connection to {str(engine_mysql.url)} failed:", e)

#for i in range(1, 10):
 #   a = f"""
  #      INSERT INTO usersNuevo (user_first, user_last, user_email, user_uid, user_pwd)
   #     VALUES ('usuario_{i}','smith_{i}','smith_{i}@hotmail.com', 'smth_{i}', 'smth_{i*2}');
    #    """
   # %sql $a

tabla_mysql = "usersNuevo"
usuarios = %sql SELECT * FROM usersNuevo LIMIT 10;
print(usuarios)
connection_mysql.close()

#postgresql
psw_psql = os.getenv("PSQL_PSW")
DATABASE_URL_postgres = f"postgresql://root:{psw_psql}@127.0.0.1:5432/company_db"

try:
    engine_postgres = create_engine(DATABASE_URL_postgres)
    connection_postgres = engine_postgres.connect()
    # %sql $DATABASE_URL_postgres
    print(f"Connected successfully to {str(engine_postgres.url)}!")
except Exception as e:
    print(f"Connection to {str(engine_postgres.url)} failed:", e)

empleados = %sql SELECT * FROM employees;
print(empleados)
#for i in range(25, 30):
 #   a = f"""
  #  INSERT INTO jobs (job_id, job_title, min_salary, max_salary)
   # VALUES ('{str(i)}','al_pedo_{i}',{7000*i}, {i*20000});
    #"""
    #%sql $a
connection_postgres.close()
# Out:
# Connected successfully to mysql+mysqlconnector://root:***@127.0.0.1:3306/exampleDB!
#  * mysql+mysqlconnector://root:***@127.0.0.1:3306/exampleDB
# 10 rows affected.
# +---------+------------+-----------+---------------------+----------+-----------+
# | user_id | user_first | user_last |      user_email     | user_uid |  user_pwd |
# +---------+------------+-----------+---------------------+----------+-----------+
# |    1    |   Danna    |   Silvio  |  rockstar@gmail.com |   fn12   | 123prueba |
# |    2    |   Daniel   | Rodriguez |  dmontiel@gmail.com |   hla1   |  user123  |
# |    3    |   Andre    |   Campo   |     as@gmail.com    |  as123   |   pass12  |
# |    4    |    Mari    |   Athens  |     ma@gmail.com    | mari231  |   desa45  |
# |    5    |    Lupe    |    Zeng   |     lp@gmail.com    |  lup58   |   ret35   |
# |    6    | usuario_0  |  smith_0  | smith_0@hotmail.com |  smth_0  |   smth_0  |
# ...

# %%
#Metodo with para conectarse al database y que se cierre la conexion automaticamente
#mysql
psw_mysql = os.getenv("MYSQL_PSW")
DATABASE_URL_mysql = f"mysql+mysqlconnector://root:{psw_mysql}@127.0.0.1:3306/exampleDB"

with create_engine(DATABASE_URL_mysql).connect() as mysql_conn:
    print(f"Connected to MySQL : {DATABASE_URL_mysql}")
    # %sql $DATABASE_URL_mysql
    #for i in range(15, 20):
        #a = f"""
        #INSERT INTO usersNuevo (user_first, user_last, user_email, user_uid, user_pwd)
        #VALUES ('usuario_{i}','smith_{i}','smith_{i}@hotmail.com', 'smth_{i}', 'smth_{i*2}');
        #"""
        #%sql $a
    tabla_mysql = "usersNuevo"
    usuarios = %sql SELECT * FROM usersNuevo LIMIT 10;
    print(usuarios)
        
#postgresql
psw_psql = os.getenv("PSQL_PSW")
DATABASE_URL_postgres = f"postgresql://root:{psw_psql}@127.0.0.1:5432/company_db"
with create_engine(DATABASE_URL_postgres).connect() as pg_conn:
    print(f"Connected to PostgreSQL: {DATABASE_URL_postgres}")
    # %sql $DATABASE_URL_postgres
    #for i in range(10, 15):
        #b = f"""
        #INSERT INTO jobs (job_id, job_title, min_salary, max_salary)
        #VALUES ('{str(i)}','al_pedo_{i}',{7000*i}, {i*20000});
        #"""
        #%sql $b
    empleados = %sql SELECT * FROM employees;
    print(empleados)
# Out:
# Connected to MySQL : mysql+mysqlconnector://root:toor@127.0.0.1:3306/exampleDB
#  * mysql+mysqlconnector://root:***@127.0.0.1:3306/exampleDB
#    postgresql://root:***@127.0.0.1:5432/company_db
# 10 rows affected.
# +---------+------------+-----------+---------------------+----------+-----------+
# | user_id | user_first | user_last |      user_email     | user_uid |  user_pwd |
# +---------+------------+-----------+---------------------+----------+-----------+
# |    1    |   Danna    |   Silvio  |  rockstar@gmail.com |   fn12   | 123prueba |
# |    2    |   Daniel   | Rodriguez |  dmontiel@gmail.com |   hla1   |  user123  |
# |    3    |   Andre    |   Campo   |     as@gmail.com    |  as123   |   pass12  |
# |    4    |    Mari    |   Athens  |     ma@gmail.com    | mari231  |   desa45  |
# |    5    |    Lupe    |    Zeng   |     lp@gmail.com    |  lup58   |   ret35   |
# |    6    | usuario_0  |  smith_0  | smith_0@hotmail.com |  smth_0  |   smth_0  |
# ...

# %%
nombre = "Jane"
# %sql SELECT * FROM employees WHERE f_name = :nombre;
# Out:
#    mysql+mysqlconnector://root:***@127.0.0.1:3306/exampleDB
#  * postgresql://root:***@127.0.0.1:5432/company_db
# 1 rows affected.
# [(2, 'Jane', 'Smith', '987-65-4321', datetime.date(1990, 9, 15), 'F', '456 Oak St', 2, Decimal('95000'), 1, 2)]
